# %% [markdown]
# <a href="https://colab.research.google.com/github/ArouaFechtaoui/Computer-Vision-Projects/blob/main/DeepGuardAV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

base_path = "/content/drive/MyDrive/Datasets"
fake_path = os.path.join(base_path, "Fake-vid")
real_path = os.path.join(base_path, "Real-vid")

fake_videos = os.listdir(fake_path)
real_videos = os.listdir(real_path)

print("Nombre de vidéos fake :", len(fake_videos))
print("Nombre de vidéos real :", len(real_videos))
# Out:
# Nombre de vidéos fake : 4361
# Nombre de vidéos real : 4361
